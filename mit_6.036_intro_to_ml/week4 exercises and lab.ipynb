# %% [markdown]
# # Exercises

# %%
import numpy as np
# Exercies

xy = [
     ((3, 2), +1), ((1, 1), -1), ((4, 2), -1) 
]
th = (1,1)
th0 =-4

for xi, yi in xy:
    print(xi,yi, yi* ( xi[0] * th[0] + xi[1] * th[1] + th0) / (th[0]**2+th[1]**2)**0.5)
# Out:
# (3, 2) 1 0.7071067811865475
# (1, 1) -1 1.414213562373095
# (4, 2) -1 -1.414213562373095

# %%
# 0.7071067811865475, 1.414213562373095, -1.414213562373095

# %%
data = np.array([[1, 1, 3, 3],[3, 1, 4, 2]])
labels = np.array([[-1, -1, 1, 1]])
th = np.array([[0, 1]]).T
th0 = -3

labels * (th.T @ data + th0) / np.linalg.norm(th)
# Out:
# array([[ 0.,  2.,  1., -1.]])

# %% [markdown]
# # Lab
#
# ## 1)

# %% [markdown]
# ```
# (2 x + 3) ** 2
# 2 * ( 2x + 3) * 2 = 0
# x = -3/2
#
# |1 - 8*e|  < 1
# -1 < 1 - 8*e < 1
# -2 < -8*e < 0
# 1/4 > e > 0
#
# 1 - 8*e = 0
# 1 - 8/8 = 0
#
# x(k)+3/2=(1−8η)**k(x(0)+3/2).
#
# 1 - 8 * 10 / 100
# (100 - 8 * 10 ) ^ k / 100 ^ k
#
# 1 - 8 * 11 / 100
# 1 - 8 * 12 / 100
#
# x = 10..15
# xk + 3/2 = (x0 + 3/2) * (1 - 8*x/100)^k
#
#
# ```
#
# ![image.png](attachment:1a6fe4f5-af16-41f5-909c-6be3c44f79cd.png)

# %% [markdown]
# ## 2) Where to meet?
#
#
# > 2A) Pose this problem as an (unconstrained) optimization problem. Assume there are nnn friends and the iii-th friend is located at lil_ili​. Denote the location of the party by ppp. What is the objective as a function of ppp? Write it down.
#
#
# ```
# l_i - location of i-th friend
# p - party location
#
# ```
#
# ![image.png](attachment:b253b967-4013-4d9e-a398-4d20f5cf6b3e.png)
#
# > 2B) Compute the gradient (write down/show your computation). Where is it zero?
#
# ![image.png](attachment:b50ae1d7-51c8-431d-b2c5-4bf59db845c3.png)
